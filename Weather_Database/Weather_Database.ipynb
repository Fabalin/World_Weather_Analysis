# %% [markdown]
# # Import Dependencies

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import Request Library and API key 
import requests 
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %% [markdown]
# # Create Random Latitudes and Longitudes to Get Cities

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ## Determine Cities using Citipy

# %%
# Use the citipy module to determine city based on latitude and longitude.
# Citipy searches the nearest city to the coordinates, with a minimum population of 500. 
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count >= 625
print(f"{len(cities)} unique cities identified from 1,500 randomly generated coordinates.")
# Out:
# 751 unique cities identified from 1,500 randomly generated coordinates.

# %% [markdown]
# # Retrieve Data Using Cities Generated

# %%
# Build Basic URL for API call 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Initialize Empty List and Counters for Data Retrieval

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        # Gets reset to 1 once 50 cities have been processed 
        record_count = 1
        # Prevents time-out errors since OpenWeatherMap API only allows 50 retrievals per min for Free 
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count. Enumerates the total number of cities processed. 
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | severo-kurilsk
# Processing Record 2 of Set 1 | bang saphan
# Processing Record 3 of Set 1 | plyussa
# Processing Record 4 of Set 1 | san cristobal
# Processing Record 5 of Set 1 | karup
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | beian
# Processing Record 8 of Set 1 | thompson
# Processing Record 9 of Set 1 | torbay
# Processing Record 10 of Set 1 | kavieng
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | touros
# Processing Record 13 of Set 1 | puerto escondido
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | abu kamal
# Processing Record 16 of Set 1 | tual
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | sao joao da barra
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | cabo san lucas
# Processing Record 22 of Set 1 | bathsheba
# Processing Record 23 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 1 | buchanan
# Processing Record 25 of Set 1 | ewa beach
# Processing Record 26 of Set 1 | bankura
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | prescott
# Processing Record 29 of Set 1 | tochio
# Processing Record 30 of Set 1 | kaitangata
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | opuwo
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | ahipara
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | sidi ali
# Processing Record 39 of Set 1 | kutum
# Processing Record 40 of Set 1 | khor
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | airai
# Processing Record 44 of Set 1 | shihezi
# Processing Record 45 of Set 1 | niono
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | srednekolymsk
# Processing Record 48 of Set 1 | grand gaube
# Processing Record 49 of Set 1 | karachi
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | villiers
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | port elizabeth
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | los llanos de aridane
# Processing Record 8 of Set 2 | lazaro cardenas
# Processing Record 9 of Set 2 | honningsvag
# Processing Record 10 of Set 2 | nanga eboko
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | nanortalik
# Processing Record 14 of Set 2 | tianpeng
# Processing Record 15 of Set 2 | kuusamo
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | tocopilla
# Processing Record 18 of Set 2 | vanimo
# Processing Record 19 of Set 2 | husavik
# Processing Record 20 of Set 2 | katsuura
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | aljezur
# Processing Record 23 of Set 2 | dingle
# Processing Record 24 of Set 2 | sioux lookout
# Processing Record 25 of Set 2 | anloga
# Processing Record 26 of Set 2 | chapais
# Processing Record 27 of Set 2 | coquimbo
# Processing Record 28 of Set 2 | flinders
# Processing Record 29 of Set 2 | silifke
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | genhe
# Processing Record 32 of Set 2 | dhone
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | lac du bonnet
# Processing Record 35 of Set 2 | avarua
# Processing Record 36 of Set 2 | balkanabat
# Processing Record 37 of Set 2 | dubai
# Processing Record 38 of Set 2 | port-gentil
# Processing Record 39 of Set 2 | shirokiy
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | whyalla
# Processing Record 42 of Set 2 | albany
# Processing Record 43 of Set 2 | takoradi
# Processing Record 44 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 2 | atherton
# Processing Record 46 of Set 2 | kyenjojo
# Processing Record 47 of Set 2 | gravelbourg
# Processing Record 48 of Set 2 | nelson bay
# Processing Record 49 of Set 2 | camacha
# Processing Record 50 of Set 2 | margate
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | hay river
# Processing Record 3 of Set 3 | twentynine palms
# Processing Record 4 of Set 3 | neftcala
# Processing Record 5 of Set 3 | saldanha
# Processing Record 6 of Set 3 | hami
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | senmonorom
# City not found. Skipping...
# Processing Record 11 of Set 3 | yellowknife
# Processing Record 12 of Set 3 | roncesvalles
# Processing Record 13 of Set 3 | tokmak
# Processing Record 14 of Set 3 | hofn
# Processing Record 15 of Set 3 | itoman
# Processing Record 16 of Set 3 | najran
# Processing Record 17 of Set 3 | chuy
# Processing Record 18 of Set 3 | atar
# Processing Record 19 of Set 3 | keningau
# Processing Record 20 of Set 3 | harper
# Processing Record 21 of Set 3 | khatanga
# Processing Record 22 of Set 3 | seydisehir
# Processing Record 23 of Set 3 | socorro
# Processing Record 24 of Set 3 | hinton
# Processing Record 25 of Set 3 | macon
# Processing Record 26 of Set 3 | mahibadhoo
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | groningen
# Processing Record 29 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 3 | east london
# Processing Record 31 of Set 3 | leningradskiy
# Processing Record 32 of Set 3 | beira
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 3 | kotelnich
# Processing Record 36 of Set 3 | rusera
# Processing Record 37 of Set 3 | hillsborough
# Processing Record 38 of Set 3 | yarada
# Processing Record 39 of Set 3 | sogne
# Processing Record 40 of Set 3 | kapaa
# Processing Record 41 of Set 3 | esso
# Processing Record 42 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 43 of Set 3 | sitka
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | sakaiminato
# Processing Record 46 of Set 3 | acapulco
# Processing Record 47 of Set 3 | mehamn
# Processing Record 48 of Set 3 | narsaq
# Processing Record 49 of Set 3 | port macquarie
# Processing Record 50 of Set 3 | longyearbyen
# Processing Record 1 of Set 4 | kenai
# Processing Record 2 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 4 | culebra
# Processing Record 4 of Set 4 | brae
# Processing Record 5 of Set 4 | araguatins
# City not found. Skipping...
# Processing Record 6 of Set 4 | puerto el triunfo
# Processing Record 7 of Set 4 | atambua
# Processing Record 8 of Set 4 | tuatapere
# Processing Record 9 of Set 4 | luderitz
# Processing Record 10 of Set 4 | chokurdakh
# Processing Record 11 of Set 4 | carnarvon
# Processing Record 12 of Set 4 | labuhan
# Processing Record 13 of Set 4 | aklavik
# Processing Record 14 of Set 4 | hambantota
# Processing Record 15 of Set 4 | quatre cocos
# Processing Record 16 of Set 4 | olafsvik
# Processing Record 17 of Set 4 | honiara
# Processing Record 18 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 4 | viedma
# Processing Record 20 of Set 4 | saskylakh
# Processing Record 21 of Set 4 | fort nelson
# Processing Record 22 of Set 4 | lavrentiya
# Processing Record 23 of Set 4 | saint-pierre
# Processing Record 24 of Set 4 | fallon
# Processing Record 25 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 4 | mount gambier
# Processing Record 27 of Set 4 | nemuro
# Processing Record 28 of Set 4 | jalu
# Processing Record 29 of Set 4 | kargasok
# Processing Record 30 of Set 4 | kindu
# Processing Record 31 of Set 4 | kavaratti
# Processing Record 32 of Set 4 | sovetskiy
# Processing Record 33 of Set 4 | puerto ayora
# Processing Record 34 of Set 4 | cidreira
# Processing Record 35 of Set 4 | sohag
# Processing Record 36 of Set 4 | dicabisagan
# Processing Record 37 of Set 4 | evensk
# Processing Record 38 of Set 4 | lillesand
# Processing Record 39 of Set 4 | vila franca do campo
# Processing Record 40 of Set 4 | hermanus
# Processing Record 41 of Set 4 | high level
# Processing Record 42 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 4 | algiers
# Processing Record 44 of Set 4 | xai-xai
# Processing Record 45 of Set 4 | chissamba
# Processing Record 46 of Set 4 | mayo
# Processing Record 47 of Set 4 | berberati
# Processing Record 48 of Set 4 | pacific grove
# Processing Record 49 of Set 4 | fiumicino
# Processing Record 50 of Set 4 | shirvan
# Processing Record 1 of Set 5 | tilichiki
# Processing Record 2 of Set 5 | gobabis
# Processing Record 3 of Set 5 | necochea
# Processing Record 4 of Set 5 | upernavik
# Processing Record 5 of Set 5 | makung
# City not found. Skipping...
# Processing Record 6 of Set 5 | turayf
# Processing Record 7 of Set 5 | plettenberg bay
# Processing Record 8 of Set 5 | usinsk
# Processing Record 9 of Set 5 | pedasi
# Processing Record 10 of Set 5 | olinda
# Processing Record 11 of Set 5 | faya
# Processing Record 12 of Set 5 | la asuncion
# Processing Record 13 of Set 5 | tanete
# Processing Record 14 of Set 5 | ler
# Processing Record 15 of Set 5 | itupiranga
# Processing Record 16 of Set 5 | camopi
# Processing Record 17 of Set 5 | dawlatabad
# Processing Record 18 of Set 5 | nikolskoye
# Processing Record 19 of Set 5 | sinjah
# City not found. Skipping...
# Processing Record 20 of Set 5 | trstena
# Processing Record 21 of Set 5 | jaipur hat
# City not found. Skipping...
# Processing Record 22 of Set 5 | kupang
# Processing Record 23 of Set 5 | castro
# Processing Record 24 of Set 5 | arraial do cabo
# Processing Record 25 of Set 5 | padang
# Processing Record 26 of Set 5 | kahului
# Processing Record 27 of Set 5 | sulangan
# Processing Record 28 of Set 5 | te anau
# Processing Record 29 of Set 5 | ust-kuyga
# Processing Record 30 of Set 5 | gat
# Processing Record 31 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 5 | mercedes
# Processing Record 33 of Set 5 | bandarbeyla
# Processing Record 34 of Set 5 | mapiripan
# Processing Record 35 of Set 5 | isangel
# Processing Record 36 of Set 5 | codrington
# Processing Record 37 of Set 5 | elizabeth city
# Processing Record 38 of Set 5 | oranjestad
# Processing Record 39 of Set 5 | mount isa
# Processing Record 40 of Set 5 | kosino
# Processing Record 41 of Set 5 | marawi
# Processing Record 42 of Set 5 | yulara
# Processing Record 43 of Set 5 | octeville
# Processing Record 44 of Set 5 | nguruka
# Processing Record 45 of Set 5 | ada
# Processing Record 46 of Set 5 | praia da vitoria
# Processing Record 47 of Set 5 | nome
# Processing Record 48 of Set 5 | kalmunai
# Processing Record 49 of Set 5 | pitimbu
# Processing Record 50 of Set 5 | bowen
# Processing Record 1 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 6 | karratha
# Processing Record 3 of Set 6 | richards bay
# Processing Record 4 of Set 6 | kloulklubed
# Processing Record 5 of Set 6 | port alberni
# Processing Record 6 of Set 6 | uzumlu
# City not found. Skipping...
# Processing Record 7 of Set 6 | tsumeb
# Processing Record 8 of Set 6 | zhezkazgan
# Processing Record 9 of Set 6 | lompoc
# Processing Record 10 of Set 6 | umm kaddadah
# Processing Record 11 of Set 6 | bambous virieux
# Processing Record 12 of Set 6 | kruisfontein
# Processing Record 13 of Set 6 | guerrero negro
# Processing Record 14 of Set 6 | tahta
# Processing Record 15 of Set 6 | ulladulla
# Processing Record 16 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 6 | vardo
# Processing Record 18 of Set 6 | cherskiy
# Processing Record 19 of Set 6 | willowmore
# Processing Record 20 of Set 6 | burnie
# Processing Record 21 of Set 6 | pinawa
# Processing Record 22 of Set 6 | victor harbor
# Processing Record 23 of Set 6 | jalingo
# Processing Record 24 of Set 6 | kuragino
# Processing Record 25 of Set 6 | batagay
# Processing Record 26 of Set 6 | kapoeta
# Processing Record 27 of Set 6 | victoria
# Processing Record 28 of Set 6 | new norfolk
# Processing Record 29 of Set 6 | tecoanapa
# Processing Record 30 of Set 6 | leshukonskoye
# Processing Record 31 of Set 6 | cap malheureux
# Processing Record 32 of Set 6 | turbat
# Processing Record 33 of Set 6 | miles city
# Processing Record 34 of Set 6 | gamba
# Processing Record 35 of Set 6 | luau
# Processing Record 36 of Set 6 | broome
# Processing Record 37 of Set 6 | tiksi
# Processing Record 38 of Set 6 | azle
# Processing Record 39 of Set 6 | jiaocheng
# Processing Record 40 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 6 | jumla
# Processing Record 42 of Set 6 | fuling
# Processing Record 43 of Set 6 | bilibino
# Processing Record 44 of Set 6 | saint-francois
# Processing Record 45 of Set 6 | pryozerne
# Processing Record 46 of Set 6 | porto santo
# Processing Record 47 of Set 6 | varkaus
# Processing Record 48 of Set 6 | pandan
# Processing Record 49 of Set 6 | gurskoye
# City not found. Skipping...
# Processing Record 50 of Set 6 | lichinga
# Processing Record 1 of Set 7 | montauban
# Processing Record 2 of Set 7 | la paz
# Processing Record 3 of Set 7 | havre
# Processing Record 4 of Set 7 | koutiala
# Processing Record 5 of Set 7 | manaus
# Processing Record 6 of Set 7 | berdigestyakh
# Processing Record 7 of Set 7 | porto novo
# Processing Record 8 of Set 7 | otane
# Processing Record 9 of Set 7 | turinsk
# Processing Record 10 of Set 7 | dingli
# Processing Record 11 of Set 7 | vao
# Processing Record 12 of Set 7 | kysyl-syr
# Processing Record 13 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 7 | solnechnyy
# Processing Record 15 of Set 7 | mareeba
# Processing Record 16 of Set 7 | clyde river
# Processing Record 17 of Set 7 | bealanana
# Processing Record 18 of Set 7 | taoudenni
# Processing Record 19 of Set 7 | jiuquan
# Processing Record 20 of Set 7 | palwal
# Processing Record 21 of Set 7 | parkes
# Processing Record 22 of Set 7 | port hardy
# Processing Record 23 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of Set 7 | shaoxing
# Processing Record 26 of Set 7 | kristiinankaupunki
# Processing Record 27 of Set 7 | hun
# Processing Record 28 of Set 7 | kaya
# Processing Record 29 of Set 7 | wahlstedt
# Processing Record 30 of Set 7 | pangnirtung
# Processing Record 31 of Set 7 | azul
# Processing Record 32 of Set 7 | ouadda
# Processing Record 33 of Set 7 | teguise
# Processing Record 34 of Set 7 | samarai
# Processing Record 35 of Set 7 | siyabuswa
# Processing Record 36 of Set 7 | pareora
# Processing Record 37 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 38 of Set 7 | lebu
# Processing Record 39 of Set 7 | dehloran
# Processing Record 40 of Set 7 | hovd
# Processing Record 41 of Set 7 | praya
# Processing Record 42 of Set 7 | mitu
# Processing Record 43 of Set 7 | kargopol
# Processing Record 44 of Set 7 | sotouboua
# Processing Record 45 of Set 7 | turochak
# Processing Record 46 of Set 7 | portland
# Processing Record 47 of Set 7 | bambanglipuro
# Processing Record 48 of Set 7 | rocha
# Processing Record 49 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 50 of Set 7 | teya
# Processing Record 1 of Set 8 | saint george
# Processing Record 2 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 3 of Set 8 | nouadhibou
# Processing Record 4 of Set 8 | chiang klang
# Processing Record 5 of Set 8 | marienburg
# Processing Record 6 of Set 8 | tambura
# Processing Record 7 of Set 8 | valparaiso
# Processing Record 8 of Set 8 | nuevitas
# Processing Record 9 of Set 8 | fare
# Processing Record 10 of Set 8 | bend
# Processing Record 11 of Set 8 | kirakira
# Processing Record 12 of Set 8 | aykhal
# Processing Record 13 of Set 8 | uusikaupunki
# Processing Record 14 of Set 8 | phayao
# Processing Record 15 of Set 8 | ossora
# Processing Record 16 of Set 8 | shenzhen
# Processing Record 17 of Set 8 | duluth
# Processing Record 18 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 19 of Set 8 | petrivka
# Processing Record 20 of Set 8 | alofi
# Processing Record 21 of Set 8 | yermakovskoye
# Processing Record 22 of Set 8 | klaksvik
# Processing Record 23 of Set 8 | wichian buri
# Processing Record 24 of Set 8 | souillac
# Processing Record 25 of Set 8 | kulhudhuffushi
# Processing Record 26 of Set 8 | teguldet
# Processing Record 27 of Set 8 | chernyy yar
# Processing Record 28 of Set 8 | huarmey
# Processing Record 29 of Set 8 | dondo
# Processing Record 30 of Set 8 | brookings
# Processing Record 31 of Set 8 | bereda
# Processing Record 32 of Set 8 | yuxia
# Processing Record 33 of Set 8 | norman wells
# Processing Record 34 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 8 | santiago de chuco
# Processing Record 36 of Set 8 | tripoli
# Processing Record 37 of Set 8 | cockburn town
# Processing Record 38 of Set 8 | viareggio
# Processing Record 39 of Set 8 | belmonte
# Processing Record 40 of Set 8 | praia
# Processing Record 41 of Set 8 | wanaka
# Processing Record 42 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 8 | zirgan
# Processing Record 44 of Set 8 | ponta delgada
# Processing Record 45 of Set 8 | puerto asis
# Processing Record 46 of Set 8 | ostrovnoy
# Processing Record 47 of Set 8 | tromso
# Processing Record 48 of Set 8 | ancud
# Processing Record 49 of Set 8 | ilulissat
# Processing Record 50 of Set 8 | nianzishan
# Processing Record 1 of Set 9 | luebo
# Processing Record 2 of Set 9 | cesis
# Processing Record 3 of Set 9 | berezniki
# Processing Record 4 of Set 9 | sao filipe
# Processing Record 5 of Set 9 | makinsk
# Processing Record 6 of Set 9 | dunedin
# Processing Record 7 of Set 9 | novopskov
# Processing Record 8 of Set 9 | coahuayana
# Processing Record 9 of Set 9 | bubaque
# Processing Record 10 of Set 9 | rockhampton
# Processing Record 11 of Set 9 | road town
# Processing Record 12 of Set 9 | sambava
# Processing Record 13 of Set 9 | brownsville
# Processing Record 14 of Set 9 | pevek
# Processing Record 15 of Set 9 | mabay
# Processing Record 16 of Set 9 | uchiza
# Processing Record 17 of Set 9 | manokwari
# Processing Record 18 of Set 9 | urusha
# Processing Record 19 of Set 9 | berlevag
# Processing Record 20 of Set 9 | constitucion
# Processing Record 21 of Set 9 | navolato
# Processing Record 22 of Set 9 | tuy hoa
# Processing Record 23 of Set 9 | quballat
# Processing Record 24 of Set 9 | whitehorse
# Processing Record 25 of Set 9 | okhotsk
# Processing Record 26 of Set 9 | saint-joseph
# Processing Record 27 of Set 9 | inuvik
# Processing Record 28 of Set 9 | marilia
# Processing Record 29 of Set 9 | sinop
# Processing Record 30 of Set 9 | urumqi
# Processing Record 31 of Set 9 | mazatlan
# Processing Record 32 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 9 | drumheller
# Processing Record 34 of Set 9 | jaque
# Processing Record 35 of Set 9 | inongo
# Processing Record 36 of Set 9 | coihaique
# Processing Record 37 of Set 9 | sorland
# Processing Record 38 of Set 9 | broken hill
# Processing Record 39 of Set 9 | henties bay
# Processing Record 40 of Set 9 | kadoma
# Processing Record 41 of Set 9 | tahe
# Processing Record 42 of Set 9 | faridan
# City not found. Skipping...
# Processing Record 43 of Set 9 | valentin gomez farias
# Processing Record 44 of Set 9 | nampula
# Processing Record 45 of Set 9 | atascadero
# Processing Record 46 of Set 9 | kankan
# Processing Record 47 of Set 9 | tandil
# Processing Record 48 of Set 9 | nogales
# Processing Record 49 of Set 9 | prilep
# Processing Record 50 of Set 9 | iqaluit
# Processing Record 1 of Set 10 | bengkulu
# Processing Record 2 of Set 10 | lyuban
# Processing Record 3 of Set 10 | saint anthony
# Processing Record 4 of Set 10 | andros town
# Processing Record 5 of Set 10 | koungheul
# Processing Record 6 of Set 10 | palu
# Processing Record 7 of Set 10 | pisco
# Processing Record 8 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 10 | palmer
# Processing Record 10 of Set 10 | dunda
# Processing Record 11 of Set 10 | chegdomyn
# Processing Record 12 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 10 | bulgan
# Processing Record 14 of Set 10 | beloha
# Processing Record 15 of Set 10 | songjianghe
# Processing Record 16 of Set 10 | boddam
# Processing Record 17 of Set 10 | havre-saint-pierre
# Processing Record 18 of Set 10 | mahon
# Processing Record 19 of Set 10 | punta gorda
# Processing Record 20 of Set 10 | auki
# Processing Record 21 of Set 10 | rehti
# Processing Record 22 of Set 10 | kuching
# Processing Record 23 of Set 10 | trinidad
# Processing Record 24 of Set 10 | camacupa
# Processing Record 25 of Set 10 | springbok
# Processing Record 26 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 27 of Set 10 | geraldton
# Processing Record 28 of Set 10 | balabac
# Processing Record 29 of Set 10 | tessalit
# Processing Record 30 of Set 10 | tsentralnyy
# City not found. Skipping...
# Processing Record 31 of Set 10 | clarksburg
# Processing Record 32 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 33 of Set 10 | charagua
# Processing Record 34 of Set 10 | rundu
# Processing Record 35 of Set 10 | okato
# Processing Record 36 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 10 | grafton
# Processing Record 38 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 10 | nadudvar
# Processing Record 40 of Set 10 | acajutla
# Processing Record 41 of Set 10 | partyzany
# Processing Record 42 of Set 10 | latung
# Processing Record 43 of Set 10 | hamilton
# Processing Record 44 of Set 10 | dali
# Processing Record 45 of Set 10 | entre rios
# Processing Record 46 of Set 10 | baykit
# Processing Record 47 of Set 10 | terra santa
# Processing Record 48 of Set 10 | gulariya
# Processing Record 49 of Set 10 | el uvito
# Processing Record 50 of Set 10 | alatri
# Processing Record 1 of Set 11 | correntina
# Processing Record 2 of Set 11 | buraydah
# Processing Record 3 of Set 11 | mana
# Processing Record 4 of Set 11 | ust-uda
# Processing Record 5 of Set 11 | fortuna
# Processing Record 6 of Set 11 | fonte boa
# Processing Record 7 of Set 11 | payson
# Processing Record 8 of Set 11 | dembi dolo
# Processing Record 9 of Set 11 | kharakvasla
# Processing Record 10 of Set 11 | port angeles
# Processing Record 11 of Set 11 | liwale
# Processing Record 12 of Set 11 | tyumen
# Processing Record 13 of Set 11 | staroutkinsk
# Processing Record 14 of Set 11 | cap-aux-meules
# Processing Record 15 of Set 11 | borzya
# Processing Record 16 of Set 11 | yaan
# Processing Record 17 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 11 | mezen
# Processing Record 19 of Set 11 | okha
# Processing Record 20 of Set 11 | homer
# Processing Record 21 of Set 11 | salalah
# Processing Record 22 of Set 11 | vestmannaeyjar
# Processing Record 23 of Set 11 | davila
# Processing Record 24 of Set 11 | edmond
# Processing Record 25 of Set 11 | skibbereen
# Processing Record 26 of Set 11 | tevaitoa
# Processing Record 27 of Set 11 | kaduqli
# Processing Record 28 of Set 11 | santa lucia
# Processing Record 29 of Set 11 | pontes e lacerda
# Processing Record 30 of Set 11 | morrope
# Processing Record 31 of Set 11 | mecca
# Processing Record 32 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 11 | san jose
# Processing Record 34 of Set 11 | saint-georges
# Processing Record 35 of Set 11 | alice springs
# Processing Record 36 of Set 11 | valdez
# Processing Record 37 of Set 11 | mahebourg
# Processing Record 38 of Set 11 | laguna
# Processing Record 39 of Set 11 | vostok
# Processing Record 40 of Set 11 | guaratinga
# Processing Record 41 of Set 11 | ibipora
# Processing Record 42 of Set 11 | lasa
# Processing Record 43 of Set 11 | repatriacion
# Processing Record 44 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 46 of Set 11 | antofagasta
# Processing Record 47 of Set 11 | zhigansk
# Processing Record 48 of Set 11 | mizdah
# Processing Record 49 of Set 11 | emerald
# Processing Record 50 of Set 11 | monroe
# Processing Record 1 of Set 12 | arica
# Processing Record 2 of Set 12 | luwuk
# Processing Record 3 of Set 12 | yar-sale
# Processing Record 4 of Set 12 | vicksburg
# Processing Record 5 of Set 12 | kaeo
# Processing Record 6 of Set 12 | ukiah
# Processing Record 7 of Set 12 | qasigiannguit
# Processing Record 8 of Set 12 | tabou
# Processing Record 9 of Set 12 | walvis bay
# Processing Record 10 of Set 12 | tautira
# Processing Record 11 of Set 12 | port augusta
# Processing Record 12 of Set 12 | san-pedro
# Processing Record 13 of Set 12 | tsagan aman
# Processing Record 14 of Set 12 | zunyi
# Processing Record 15 of Set 12 | mbamba
# Processing Record 16 of Set 12 | birjand
# Processing Record 17 of Set 12 | lloydminster
# Processing Record 18 of Set 12 | baracoa
# Processing Record 19 of Set 12 | hualmay
# Processing Record 20 of Set 12 | kirksville
# Processing Record 21 of Set 12 | mitsamiouli
# Processing Record 22 of Set 12 | arlit
# Processing Record 23 of Set 12 | silva jardim
# Processing Record 24 of Set 12 | goderich
# Processing Record 25 of Set 12 | hobyo
# Processing Record 26 of Set 12 | tela
# Processing Record 27 of Set 12 | cabedelo
# Processing Record 28 of Set 12 | terrace
# Processing Record 29 of Set 12 | dig
# Processing Record 30 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 12 | port lincoln
# Processing Record 32 of Set 12 | gao
# Processing Record 33 of Set 12 | strezhevoy
# Processing Record 34 of Set 12 | taltal
# Processing Record 35 of Set 12 | manavalakurichi
# Processing Record 36 of Set 12 | vila velha
# Processing Record 37 of Set 12 | liverpool
# Processing Record 38 of Set 12 | rawson
# Processing Record 39 of Set 12 | ziyamet
# City not found. Skipping...
# Processing Record 40 of Set 12 | edendale
# Processing Record 41 of Set 12 | tupancireta
# Processing Record 42 of Set 12 | porto walter
# Processing Record 43 of Set 12 | nyagan
# Processing Record 44 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 12 | bridlington
# Processing Record 46 of Set 12 | rzhev
# Processing Record 47 of Set 12 | beringovskiy
# Processing Record 48 of Set 12 | kiama
# Processing Record 49 of Set 12 | sindor
# Processing Record 50 of Set 12 | dhidhdhoo
# Processing Record 1 of Set 13 | udachnyy
# Processing Record 2 of Set 13 | mnogovershinnyy
# Processing Record 3 of Set 13 | cozumel
# Processing Record 4 of Set 13 | pizhanka
# Processing Record 5 of Set 13 | umm lajj
# Processing Record 6 of Set 13 | valle nacional
# Processing Record 7 of Set 13 | erzin
# Processing Record 8 of Set 13 | kerrville
# Processing Record 9 of Set 13 | ketchikan
# Processing Record 10 of Set 13 | capao da canoa
# Processing Record 11 of Set 13 | iskateley
# Processing Record 12 of Set 13 | severobaykalsk
# Processing Record 13 of Set 13 | sorong
# Processing Record 14 of Set 13 | hervey bay
# Processing Record 15 of Set 13 | solenzo
# Processing Record 16 of Set 13 | lerwick
# Processing Record 17 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 18 of Set 13 | patiya
# Processing Record 19 of Set 13 | siniscola
# Processing Record 20 of Set 13 | wajir
# Processing Record 21 of Set 13 | magadan
# Processing Record 22 of Set 13 | lethem
# Processing Record 23 of Set 13 | joensuu
# Processing Record 24 of Set 13 | north platte
# Processing Record 25 of Set 13 | xinzhou
# Processing Record 26 of Set 13 | ladario
# Processing Record 27 of Set 13 | prince rupert
# Processing Record 28 of Set 13 | jiexiu
# Processing Record 29 of Set 13 | linhares
# Processing Record 30 of Set 13 | shemonaikha
# Processing Record 31 of Set 13 | san pedro
# Processing Record 32 of Set 13 | bonthe
# Processing Record 33 of Set 13 | atikokan
# Processing Record 34 of Set 13 | carauari
# Processing Record 35 of Set 13 | stromness
# Processing Record 36 of Set 13 | chengde
# Processing Record 37 of Set 13 | lata
# Processing Record 38 of Set 13 | acarau
# Processing Record 39 of Set 13 | half moon bay
# Processing Record 40 of Set 13 | rancho santa margarita
# Processing Record 41 of Set 13 | mayumba
# Processing Record 42 of Set 13 | benemerito de las americas
# Processing Record 43 of Set 13 | stornoway
# Processing Record 44 of Set 13 | palimbang
# Processing Record 45 of Set 13 | voh
# Processing Record 46 of Set 13 | obo
# Processing Record 47 of Set 13 | wamba
# Processing Record 48 of Set 13 | nyurba
# Processing Record 49 of Set 13 | pirgos
# Processing Record 50 of Set 13 | ushtobe
# Processing Record 1 of Set 14 | redan
# Processing Record 2 of Set 14 | tadine
# Processing Record 3 of Set 14 | basi
# Processing Record 4 of Set 14 | yurimaguas
# Processing Record 5 of Set 14 | cotacachi
# Processing Record 6 of Set 14 | sibolga
# Processing Record 7 of Set 14 | sokoto
# Processing Record 8 of Set 14 | leh
# Processing Record 9 of Set 14 | chulman
# Processing Record 10 of Set 14 | bure
# Processing Record 11 of Set 14 | axim
# Processing Record 12 of Set 14 | lichtenburg
# Processing Record 13 of Set 14 | brownfield
# Processing Record 14 of Set 14 | klyuchi
# Processing Record 15 of Set 14 | tambacounda
# Processing Record 16 of Set 14 | lodingen
# Processing Record 17 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 18 of Set 14 | barcelos
# Processing Record 19 of Set 14 | bartica
# Processing Record 20 of Set 14 | amahai
# Processing Record 21 of Set 14 | corrales
# Processing Record 22 of Set 14 | puerto maldonado
# Processing Record 23 of Set 14 | turukhansk
# Processing Record 24 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 14 | san patricio
# Processing Record 26 of Set 14 | yumen
# Processing Record 27 of Set 14 | ellisras
# Processing Record 28 of Set 14 | namatanai
# Processing Record 29 of Set 14 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 30 of Set 14 | jiangyou
# Processing Record 31 of Set 14 | halifax
# Processing Record 32 of Set 14 | vila do maio
# Processing Record 33 of Set 14 | koraput
# Processing Record 34 of Set 14 | santa comba
# Processing Record 35 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 14 | talnakh
# Processing Record 37 of Set 14 | mandan
# Processing Record 38 of Set 14 | maceio
# Processing Record 39 of Set 14 | bahia blanca
# Processing Record 40 of Set 14 | roald
# Processing Record 41 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 42 of Set 14 | marsa matruh
# Processing Record 43 of Set 14 | bontang
# Processing Record 44 of Set 14 | nivala
# Processing Record 45 of Set 14 | havelock
# Processing Record 46 of Set 14 | pangody
# Processing Record 47 of Set 14 | makat
# Processing Record 48 of Set 14 | san rafael del sur
# Processing Record 49 of Set 14 | trebic
# Processing Record 50 of Set 14 | sinjar
# Processing Record 1 of Set 15 | hokitika
# Processing Record 2 of Set 15 | caconda
# Processing Record 3 of Set 15 | rapid valley
# Processing Record 4 of Set 15 | foumban
# Processing Record 5 of Set 15 | gorele
# Processing Record 6 of Set 15 | powell
# Processing Record 7 of Set 15 | pailon
# Processing Record 8 of Set 15 | arman
# Processing Record 9 of Set 15 | gayny
# Processing Record 10 of Set 15 | zhuanghe
# Processing Record 11 of Set 15 | yicheng
# Processing Record 12 of Set 15 | kenora
# Processing Record 13 of Set 15 | san ramon
# Processing Record 14 of Set 15 | neuquen
# Processing Record 15 of Set 15 | akyab
# Processing Record 16 of Set 15 | mungwi
# Processing Record 17 of Set 15 | longido
# Processing Record 18 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 15 | seymchan
# Processing Record 21 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 22 of Set 15 | assiniboia
# Processing Record 23 of Set 15 | anchorage
# Processing Record 24 of Set 15 | grindavik
# Processing Record 25 of Set 15 | cururupu
# Processing Record 26 of Set 15 | zyryanka
# Processing Record 27 of Set 15 | bogande
# Processing Record 28 of Set 15 | samfya
# Processing Record 29 of Set 15 | buncrana
# Processing Record 30 of Set 15 | ambilobe
# Processing Record 31 of Set 15 | puerto baquerizo moreno
# Processing Record 32 of Set 15 | la ronge
# Processing Record 33 of Set 15 | iquique
# Processing Record 34 of Set 15 | arnes
# Processing Record 35 of Set 15 | quang ngai
# Processing Record 36 of Set 15 | bundaberg
# Processing Record 37 of Set 15 | hailun
# Processing Record 38 of Set 15 | mongo
# Processing Record 39 of Set 15 | boma
# Processing Record 40 of Set 15 | almansa
# Processing Record 41 of Set 15 | lorengau
# Processing Record 42 of Set 15 | wawa
# Processing Record 43 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 15 | esil
# Processing Record 45 of Set 15 | williams lake
# Processing Record 46 of Set 15 | wajima
# Processing Record 47 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 15 | cumana
# Processing Record 49 of Set 15 | feijo
# Processing Record 50 of Set 15 | pervomayskoye
# Processing Record 1 of Set 16 | sarangani
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check the length of the cities_data dictionary 
print(f"Weather data for {len(city_data)} cities were retrieved from OpenWeatherMap API")
# Out:
# Weather data for 692 cities were retrieved from OpenWeatherMap API

# %%
# Convert to DataFrame 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Severo-Kurilsk      RU  50.6789  156.1250     30.09        68          99
# 1     Bang Saphan      TH  11.2126   99.5117     76.06        91          80
# 2         Plyussa      RU  58.4308   29.3654     34.30        99         100
# 3   San Cristobal      VE   7.7669  -72.2250     71.58        60          33
# 4           Karup      DK  56.3067    9.1684     41.58        81          13
# 5         Rikitea      PF -23.1203 -134.9692     79.99        71         100
# 6           Beian      NO  63.6559    9.5683     46.49        93          75
# 7        Thompson      CA  55.7435  -97.8558     32.16       100         100
# 8          Torbay      CA  47.6666  -52.7314     29.57        77          70
# 9         Kavieng      PG  -2.5744  150.7967     85.33        63          61
#
#    Wind Speed           Current Description
# 0       10.47               overcast clouds
# 1        3.04                 broken clouds
# 2        2.15               overcast clouds
# 3        0.60              scattered clouds
# 4        8.05                    few clouds
# 5       13.73               overcast clouds
# 6       27.63  light intensity drizzle rain
# 7       11.50               overcast clouds
# 8        7.00                 broken clouds
# 9        7.61                 broken clouds

# %% [markdown]
# ### Export Data as a CSV file WeatherPy_Database.csv

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
